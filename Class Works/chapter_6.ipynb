# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Recognizing missing data

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, np.nan, 30],         # Bob's Age is missing
    'Salary': [50000, 60000, np.nan] # Charlie's Salary is missing
})

# 1. The Mask (Hard to read for big data)
print(df.isnull())
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2  False  False    True

# %%
# 2. The Count (The Standard Way)
print("Missing values per column:")
print(df.isnull().sum())
type(df.isnull().sum())
# Out:
# Missing values per column:
# Name      0
# Age       1
# Salary    1
# dtype: int64
# pandas.core.series.Series

# %% [markdown]
# #### Handling Missing Data

# %% [markdown]
# #### Removing NaN values

# %%
import pandas as pd

# Original DataFrame
print("Original DataFrame:")
print(df)
print("-" * 50)

# Remove ANY row that contains at least one NaN
clean_rows = df.dropna()
print("After dropping rows with ANY NaN:")
print(clean_rows)
print("-" * 50)

# Remove ANY column that contains at least one NaN
clean_cols = df.dropna(axis=1)
print("After dropping columns with ANY NaN:")
print(clean_cols)
print("-" * 50)

# Smart drop: Remove rows ONLY if 'Name' is NaN
# (Keeps rows where other columns like Age may be NaN)
smart_drop = df.dropna(subset=["Name"])
print("After dropping rows where 'Name' is NaN:")
print(smart_drop)
print("-" * 50)

smart_drop = df.dropna(subset=["Age"])
print("After dropping rows where 'Age' is NaN:")
print(smart_drop)
print("-" * 50)

smart_drop = df.dropna(subset=["Name"],axis=1) #why error??????
print("After dropping rows where 'Name' is NaN:")
print(smart_drop)
print("-" * 50)
# Out:
# Original DataFrame:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob   NaN  60000.0
# 2  Charlie  30.0      NaN
# --------------------------------------------------
# After dropping rows with ANY NaN:
#     Name   Age   Salary
# 0  Alice  25.0  50000.0
# --------------------------------------------------
# After dropping columns with ANY NaN:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# --------------------------------------------------
# After dropping rows where 'Name' is NaN:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob   NaN  60000.0
# 2  Charlie  30.0      NaN
# --------------------------------------------------
# After dropping rows where 'Age' is NaN:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 2  Charlie  30.0      NaN
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17356\2386311675.py in ?()
#      28 print("After dropping rows where 'Age' is NaN:")
#      29 print(smart_drop)
#      30 print("-" * 50)
#      31
# ---> 32 smart_drop = df.dropna(subset=["Name"],axis=1)
#      33 print("After dropping rows where 'Name' is NaN:")
#      34 print(smart_drop)
#      35 print("-" * 50)
#
# ~\OneDrive\(BCSIT)Semester V\Data Science (Fundamentals)\data_env\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6688             ax = self._get_axis(agg_axis)
#    6689             indices = ax.get_indexer_for(subset)
#    6690             check = indices == -1
#    6691             if check.any():
# -> 6692                 raise KeyError(np.array(subset)[check].tolist())
#    6693             agg_obj = self.take(indices, axis=agg_axis)
#    6694
#    6695         if thresh is not lib.no_default:
#
# KeyError: ['Name']

# %%
# 1. Fill with Zero (Good for things like 'Debt' or 'Points')
df_zero = df.fillna(0)
print("After filling NaN values with 0 ")
print(df_zero)
print("-" * 50)
print(df_zero.dtypes)


df_zero = df.fillna("👻")
print("After filling NaN values with 0 ")
print(df_zero)
print("-" * 50)
df_zero.dtypes
# Out:
# After filling NaN values with 0
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob   0.0  60000.0
# 2  Charlie  30.0      0.0
# --------------------------------------------------
# Name       object
# Age       float64
# Salary    float64
# dtype: object
# After filling NaN values with 0
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob     👻  60000.0
# 2  Charlie  30.0        👻
# --------------------------------------------------
# Name      object
# Age       object
# Salary    object
# dtype: object

# %% [markdown]
# #### Statistical Imputation

# %%
print("Before filling NaN in Age:")
print(df)
print("-" * 50)

mean_age = df["Age"].mean()
print(f"Mean Age: {mean_age}")
print("-" * 50)

# Fill NaN values in Age with the mean

df["Age"] = df["Age"].fillna(mean_age)
# df["Age"].fillna(mean_age)
# print(df)
# After filling NaN
print("After filling NaN in Age with mean:")
print(df)
print("-" * 50)



print("Before filling NaN in Salary:")
print(df)
print("-" * 50)

med_salary = df["Salary"].median()
print(f"Median salary: {med_salary}")
print("-" * 50)

# Fill NaN values in Age with the mean
# df["Age"] = df["Age"].fillna(mean_age)
df["Salary"]=df["Salary"].fillna(med_salary)
# print(df)
# After filling NaN
print("After filling NaN in Salary with median:")
print(df)
print("-" * 50)
# Out:
# Before filling NaN in Age:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob  27.5  60000.0
# 2  Charlie  30.0  55000.0
# --------------------------------------------------
# Mean Age: 27.5
# --------------------------------------------------
# After filling NaN in Age with mean:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob  27.5  60000.0
# 2  Charlie  30.0  55000.0
# --------------------------------------------------
# Before filling NaN in Salary:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob  27.5  60000.0
# 2  Charlie  30.0  55000.0
# --------------------------------------------------
# Median salary: 55000.0
# --------------------------------------------------
# After filling NaN in Salary with median:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob  27.5  60000.0
# 2  Charlie  30.0  55000.0
# --------------------------------------------------
